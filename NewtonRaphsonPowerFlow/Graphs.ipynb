# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.array([0.0036156327861802937, 0.00027976052404044303, 2.1845102075315904e-05, 1.6773455775921115e-06, 1.2872455780981357e-07, 9.878394606355388e-09, 7.580714469359215e-10])
x = range(y.size + 1)[1:]
plt.plot(x, y)
plt.title('Case 3: Change in $||\Delta\\alpha_{CL}-\Delta\\alpha_{HHL}||_2$ Per Iteration')
plt.xlabel('Iteration')
plt.ylabel('$||\Delta\\alpha_{CL}-\Delta\\alpha_{HHL}||_2$')
plt.show()

# %%
y = np.array([0.0034224432175341173, 0.0005046011064480931, 1.114430469323976e-05, 1.31933508222617e-07, 3.495018015748977e-08, 8.372903132479598e-09, 1.9884861347990665e-09, 4.705941966992452e-10, 1.1138415997265951e-10, 2.636044579342228e-11, 6.238631704810493e-12])
x = range(y.size + 1)[1:]
plt.plot(x, y)
plt.title('Case 9Q: Change in $||\Delta\\alpha_{CL}-\Delta\\alpha_{HHL}||_2$ Per Iteration')
plt.xlabel('Iteration')
plt.ylabel('$||\Delta\\alpha_{CL}-\Delta\\alpha_{HHL}||_2$')
plt.show()
